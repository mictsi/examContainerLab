// %% [markdown]
// # Hello, World! — C++17
//
// Run every cell (`Shift+Enter`) to check the kernel works. Use these notebooks to get familiar with the environment before an exam.

// %%
#include <iostream>
std::cout << "Hello, World! from C++" << __cplusplus / 100 % 100 << std::endl;

// %% [markdown]
// A tiny computation, to prove code really runs:

// %%
#include <numeric>
#include <vector>
std::vector<int> v(10);
std::iota(v.begin(), v.end(), 1);
std::cout << "1 + 2 + ... + 10 = " << std::accumulate(v.begin(), v.end(), 0) << std::endl;

// %% [markdown]
// # Hello, World! — C
//
// Run every cell (`Shift+Enter`) to check the kernel works. Use these notebooks to get familiar with the environment before an exam.

// %%
#include <stdio.h>

int main(void) {
    printf("Hello, World! from C (%ld-bit)\n", 8 * sizeof(void *));
    return 0;
}

// %% [markdown]
// A tiny computation, to prove code really runs:

// %%
#include <stdio.h>

int main(void) {
    int total = 0;
    for (int i = 1; i <= 10; i++) total += i;
    printf("1 + 2 + ... + 10 = %d\n", total);
    return 0;
}

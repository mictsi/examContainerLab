// %% [markdown]
// # Hello, World! — Java
//
// Run every cell (`Shift+Enter`) to check the kernel works. Use these notebooks to get familiar with the environment before an exam.

// %%
System.out.println("Hello, World! from Java " + Runtime.version());

// %% [markdown]
// A tiny computation, to prove code really runs:

// %%
int total = java.util.stream.IntStream.rangeClosed(1, 10).sum();
System.out.println("1 + 2 + ... + 10 = " + total);

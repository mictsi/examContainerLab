# %% [markdown]
# # Visualization Exam — R Graphics
#
# **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.

# %%
library(ggplot2)
options(repr.plot.width = 8, repr.plot.height = 5)  # plot size in Jupyter

# %% [markdown]
# ## Task 1 — Base graphics (2 points)
#
# With **base R** graphics, plot $\sin(x)$ for $x \in [0, 4\pi]$ as a line, add $\cos(x)$ in another color with `lines()`, and add a legend.

# %%
x <- seq(0, 4 * pi, length.out = 400)
# TODO

# %% [markdown]
# ## Task 2 — Histogram + density (3 points)
#
# For the sample below, draw a histogram scaled to density (`freq = FALSE`) and overlay the estimated density curve (`lines(density(...))`).

# %%
set.seed(1)
heights <- rnorm(500, mean = 170, sd = 8)
# TODO

# %% [markdown]
# ## Task 3 — ggplot2 scatter (3 points)
#
# Using `mtcars`, make a ggplot2 scatter plot of `hp` (x) vs `mpg` (y), colored by `factor(cyl)`, with a linear trend line (`geom_smooth(method = "lm")`), proper labels and a title.

# %%
# TODO

# %% [markdown]
# ## Task 4 — ggplot2 boxplot + facets (2 points)
#
# With `ggplot2` and the built-in `iris` data set, draw boxplots of `Sepal.Length` per `Species` **and** facet the plot by species (`facet_wrap(~ Species, scales = "free_x")`).

# %%
# TODO

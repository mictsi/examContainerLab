# %% [markdown]
# # Programming Exam — Python
#
# **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.

# %% [markdown]
# ## Task 1 — Prime test (3 points)
#
# Implement `is_prime(n)` returning `True` if `n` is a prime number, `False` otherwise. `n` may be any integer (negative numbers, 0 and 1 are not prime).

# %%
def is_prime(n: int) -> bool:
    # TODO: your implementation
    ...

# %%
# Self-check — must run without errors
assert is_prime(2) and is_prime(13) and is_prime(97)
assert not is_prime(1) and not is_prime(0) and not is_prime(-7)
assert not is_prime(91)  # 7 * 13
print('Task 1 OK')

# %% [markdown]
# ## Task 2 — Word frequency (3 points)
#
# Implement `word_count(text)` returning a `dict` mapping each lowercase word to how often it occurs. Words are separated by whitespace; strip the punctuation characters `.,!?` from the ends of each word.

# %%
def word_count(text: str) -> dict:
    # TODO: your implementation
    ...

# %%
# Self-check
wc = word_count('The cat saw the cat. The cat ran!')
assert wc == {'the': 3, 'cat': 3, 'saw': 1, 'ran': 1}
print('Task 2 OK')

# %% [markdown]
# ## Task 3 — Class design (4 points)
#
# Implement a class `BankAccount` with:
#
# - constructor taking an initial `balance` (default `0`)
# - `deposit(amount)` and `withdraw(amount)` methods
# - `withdraw` raises `ValueError` if the amount exceeds the balance
# - a read-only property `balance`

# %%
class BankAccount:
    # TODO: your implementation
    ...

# %%
# Self-check
acc = BankAccount(100)
acc.deposit(50)
acc.withdraw(30)
assert acc.balance == 120
try:
    acc.withdraw(1000)
    raise AssertionError('expected ValueError')
except ValueError:
    pass
print('Task 3 OK')

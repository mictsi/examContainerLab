// %% [markdown]
// # Programming Exam — C++17
//
// **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.
//
// > **Note:** this kernel (cling) interprets C++ incrementally — you can define a function in one cell and use it in the next, and a trailing expression displays its value.

// %% [markdown]
// ## Warm-up (0 points)

// %%
#include <iostream>
#include <vector>
#include <algorithm>
#include <numeric>
#include <string>
std::cout << "Hello from C++17!" << std::endl;

// %% [markdown]
// ## Task 1 — STL algorithms (3 points)
//
// Given the vector below, compute the sum of the squares of all even elements using `std::accumulate` (or a range-based loop). Expected result: `4 + 16 + 36 = 56`.

// %%
std::vector<int> v{1, 2, 3, 4, 5, 6};
// TODO: compute and display the result

// %% [markdown]
// ## Task 2 — Function templates (3 points)
//
// Write a function template `T clamp3(T value, T low, T high)` that restricts `value` to the range `[low, high]` (without using `std::clamp`). Show it works for `int` and `double`.

// %%
// TODO: template definition

// %%
// Tests — should display 5, 1.5
// clamp3(9, 0, 5)
// clamp3(1.5, 1.0, 2.0)

// %% [markdown]
// ## Task 3 — Structs & sorting (4 points)
//
// Define `struct Student { std::string name; double grade; };`, create a vector of at least four students, sort it by descending grade with `std::sort` and a lambda, and print the ranking.

// %%
// TODO

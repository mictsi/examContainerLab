# %% [markdown]
# # Programming Exam — Perl
#
# **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.
#
# > **Note:** the value of the last expression in a cell is displayed; use `print`/`say` for explicit output.

# %% [markdown]
# ## Warm-up (0 points)

# %%
use strict; use warnings;
print "Hello from Perl $^V\n";

# %% [markdown]
# ## Task 1 — Regular expressions (3 points)
#
# Extract all email addresses from the text below into an array `@emails` and print them one per line. Expected: two addresses.

# %%
my $text = 'Contact alice\@uni.edu or bob.smith\@lab.uni.edu for details; NOT-an-email\@ nope.';
# TODO: fill @emails using a regex
my @emails;
print "$_\n" for @emails;

# %% [markdown]
# ## Task 2 — Hashes (3 points)
#
# Count how often each word occurs in the sentence below (case-insensitive) using a hash, then print the counts sorted by word.

# %%
my $sentence = 'the quick brown fox jumps over the lazy dog the fox';
# TODO

# %% [markdown]
# ## Task 3 — Subroutines (4 points)
#
# Write a subroutine `factorial($n)` (iterative or recursive) and print `factorial(10)` — expected `3628800`.

# %%
sub factorial {
    # TODO
}
print factorial(10), "\n";

# %% [markdown]
# # Basic Math Exam — Python / SymPy
#
# **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.

# %%
import sympy as sp
import numpy as np
sp.init_printing()
x = sp.symbols('x')

# %% [markdown]
# ## Task 1 — Exact arithmetic (2 points)
#
# Compute $\frac{1}{3} + \frac{1}{4} + \frac{1}{5}$ **exactly** (as a fraction, not a float) using `sp.Rational`. Store it in `r`.

# %%
r = ...  # TODO
assert r == sp.Rational(47, 60)
r

# %% [markdown]
# ## Task 2 — Quadratic equation (2 points)
#
# Solve $2x^2 - 4x - 6 = 0$ with `sp.solve` and store the list of solutions in `roots`.

# %%
roots = ...  # TODO
assert set(roots) == {-1, 3}
roots

# %% [markdown]
# ## Task 3 — Limit (2 points)
#
# Compute $\lim_{x \to 0} \frac{\sin(x)}{x}$ with `sp.limit` and store it in `L`.

# %%
L = ...  # TODO
assert L == 1
L

# %% [markdown]
# ## Task 4 — Simple derivative (2 points)
#
# Differentiate $g(x) = x^3 - 5x + 2$ and evaluate the derivative at $x = 2$. Store the number in `slope`. (Expected: `7`.)

# %%
slope = ...  # TODO
assert slope == 7
slope

# %% [markdown]
# ## Task 5 — Graph a parabola (2 points)
#
# Plot $g(x) = x^3 - 5x + 2$ for $x \in [-3, 3]$ with matplotlib, and mark its roots on the plot (use `np.roots([1, 0, -5, 2])`). Axes labels + grid required.

# %%
import matplotlib.pyplot as plt
# TODO

# %% [markdown]
# # Visualization Exam — Plotting & Graphing (Python)
#
# **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1 — Function graphing (2 points)
#
# Graph $\sin(x)$ and $\cos(x)$ for $x \in [0, 4\pi]$ **in one figure**, with a legend, axis labels, a title and a grid.

# %%
# TODO

# %% [markdown]
# ## Task 2 — Histogram (2 points)
#
# Draw a histogram (30 bins) of the sample below and add a vertical red dashed line at the sample mean.

# %%
rng = np.random.default_rng(7)
sample = rng.normal(loc=170, scale=8, size=1000)
# TODO

# %% [markdown]
# ## Task 3 — Bar chart from a DataFrame (2 points)
#
# Make a bar chart of the students-per-course data below, sorted descending, with the count printed above each bar.

# %%
df = pd.DataFrame({
    'course':   ['Calculus', 'Algebra', 'Statistics', 'Geometry', 'Logic'],
    'students': [124, 87, 156, 45, 62],
})
# TODO

# %% [markdown]
# ## Task 4 — Subplots (2 points)
#
# Create a 2×2 figure showing $x$, $x^2$, $x^3$ and $\sqrt{x}$ for $x \in [0, 5]$, one function per panel, each with its own title. Use `plt.subplots(2, 2)`.

# %%
# TODO

# %% [markdown]
# ## Task 5 — Parametric / polar curve (1 point)
#
# Graph the spiral $r = \theta$ for $\theta \in [0, 6\pi]$ (hint: `plt.subplot(projection="polar")`, or convert to x/y).

# %%
# TODO

# %% [markdown]
# ## Task 6 — Interactive plot (1 point)
#
# Recreate Task 1 as an **interactive** plotly figure (`plotly.express.line` — hint: build a DataFrame with columns `x`, `value`, `function` or pass `y=[...]`).

# %%
import plotly.express as px
# TODO

# %% [markdown]
# ## Demo — 3D surface (not graded)
#
# Run the cell below: the environment supports 3D graphing too.

# %%
from matplotlib import cm
X, Y = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))
Z = np.sin(np.sqrt(X**2 + Y**2))
fig, ax = plt.subplots(subplot_kw={'projection': '3d'}, figsize=(7, 5))
ax.plot_surface(X, Y, Z, cmap=cm.viridis)
ax.set_title('z = sin(sqrt(x² + y²))')
plt.show()

# %% [markdown]
# # Statistics Exam — R
#
# **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.

# %% [markdown]
# ## Task 1 — Descriptive statistics (2 points)
#
# For the vector `x` below, compute the mean, median and standard deviation and store them in `x_mean`, `x_median`, `x_sd`.

# %%
set.seed(42)
x <- rnorm(200, mean = 10, sd = 3)
x_mean   <- NA  # TODO
x_median <- NA  # TODO
x_sd     <- NA  # TODO
c(x_mean, x_median, x_sd)

# %% [markdown]
# ## Task 2 — Function (3 points)
#
# Write a function `fib(n)` that returns the first `n` Fibonacci numbers as a vector (starting `1, 1, 2, ...`).

# %%
fib <- function(n) {
  # TODO
}
stopifnot(identical(fib(7), c(1, 1, 2, 3, 5, 8, 13)))
fib(10)

# %% [markdown]
# ## Task 3 — Data frames (3 points)
#
# Using the built-in `mtcars` data set: select the cars with 6 or more cylinders, sort them by descending horsepower (`hp`) and store the result in `strong_cars`. Show the top 5 rows.

# %%
strong_cars <- NULL  # TODO
head(strong_cars, 5)

# %% [markdown]
# ## Task 4 — Plotting (2 points)
#
# Create a scatter plot of `mpg` versus `wt` from `mtcars` with ggplot2, colored by number of cylinders, with axis labels and a title. The plot must be visible in the saved notebook.

# %%
library(ggplot2)
# TODO: your plot

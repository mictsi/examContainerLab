// %% [markdown]
// # Programming Exam — C
//
// **Rules:** Work on the copy of this notebook in `results/` — it was placed there automatically when the container started. Save often (`Ctrl+S`). Before finishing: *Kernel → Restart Kernel and Run All Cells* and check everything runs without errors. See `exams/INSTRUCTIONS.md` for details.
//
// > **Note:** every code cell must be a **complete program** with `main()`. Each cell is compiled with `gcc` and executed when run. Do not read from stdin — use the hard-coded test values given in each task.

// %% [markdown]
// ## Warm-up (0 points)
//
// Run the cell below to verify the C kernel works.

// %%
#include <stdio.h>

int main(void) {
    printf("Hello from C!\n");
    return 0;
}

// %% [markdown]
// ## Task 1 — Multiplication table (3 points)
//
// Print a 10×10 multiplication table using nested loops. Format each number right-aligned in a 5-character field (`%5d`).

// %%
#include <stdio.h>

int main(void) {
    // TODO: nested loops
    return 0;
}

// %% [markdown]
// ## Task 2 — String reversal (4 points)
//
// Implement `void reverse(char *s)` that reverses a string in place (no library functions except `strlen`). Test it in `main` on `"container"` — expected output: `reniatnoc`.

// %%
#include <stdio.h>
#include <string.h>

void reverse(char *s) {
    // TODO
}

int main(void) {
    char word[] = "container";
    reverse(word);
    printf("%s\n", word);
    return 0;
}

// %% [markdown]
// ## Task 3 — Arrays & pointers (3 points)
//
// Implement `int max_index(const int *a, int n)` returning the index of the largest element. Test it on the array below — expected output: `5`.

// %%
#include <stdio.h>

int max_index(const int *a, int n) {
    // TODO
    return 0;
}

int main(void) {
    int data[] = {3, 41, 7, 12, 8, 99, 4};
    printf("%d\n", max_index(data, 7));
    return 0;
}
